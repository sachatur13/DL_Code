# %%
 from tensorflow.keras.applications.vgg16 import VGG16,decode_predictions,preprocess_input
 import numpy as np
 import matplotlib.pyplot as plt
 from tensorflow.keras.preprocessing.image import load_img,img_to_array,array_to_img

# %% [markdown]
# #### Using the VGG16 model from keras

# %%
vgg_16_model = VGG16()

# %%
print(vgg_16_model.summary())
# Out:
# Model: "vgg16"
# _________________________________________________________________
# Layer (type)                 Output Shape              Param #
# ...
# input_1 (InputLayer)         [(None, 224, 224, 3)]     0
# _________________________________________________________________
# block1_conv1 (Conv2D)        (None, 224, 224, 64)      1792
# _________________________________________________________________
# block1_conv2 (Conv2D)        (None, 224, 224, 64)      36928
# _________________________________________________________________
# block1_pool (MaxPooling2D)   (None, 112, 112, 64)      0
# _________________________________________________________________
# block2_conv1 (Conv2D)        (None, 112, 112, 128)     73856
# _________________________________________________________________
# block2_conv2 (Conv2D)        (None, 112, 112, 128)     147584
# _________________________________________________________________
# block2_pool (MaxPooling2D)   (None, 56, 56, 128)       0
# ...

# %%
data = load_img(r'..\images\cat.0.jpg',target_size=(224,224))

# %%
plt.imshow(data)

# %%
data_array = img_to_array(data)

# %%
data_array
# Out:
# array([[[203., 164.,  87.],
#         [206., 167.,  90.],
#         [209., 170.,  93.],
#         ...,
#         [245., 203., 119.],
#         [241., 202., 123.],
#         [239., 200., 121.]],
#
#        [[203., 164.,  87.],
#         [206., 167.,  90.],
#         [209., 170.,  93.],
#         ...,
#         [245., 205., 120.],
#         [242., 203., 124.],
#         [240., 201., 122.]],
#
#        [[203., 164.,  87.],
#         [206., 167.,  90.],
#         [209., 170.,  93.],
#         ...,
#         [245., 204., 122.],
#         [243., 204., 125.],
#         [241., 202., 123.]],
#
#        ...,
#
#        [[154., 123.,  56.],
#         [155., 124.,  57.],
#         [156., 125.,  58.],
#         ...,
#         [  3.,   3.,   1.],
#         [  3.,   3.,   1.],
#         [  3.,   3.,   1.]],
#
#        [[153., 122.,  55.],
#         [153., 122.,  55.],
#         [154., 123.,  56.],
#         ...,
#         [  2.,   2.,   0.],
#         [  2.,   2.,   0.],
# ...

# %%
reshaped_image = data_array.reshape((1,data_array.shape[0],data_array.shape[1],data_array.shape[2]))

# %%
reshaped_image.shape
# Out:
# (1, 224, 224, 3)

# %%
preprocessed_data = preprocess_input(reshaped_image)

# %%
## Prediction using VGG16
prediction = vgg_16_model.predict(preprocessed_data)

# %%
prediction_label = decode_predictions(prediction)
prediction_label = prediction_label[0][0]

print(prediction_label[1],prediction_label[2])
# Out:
# ...
# 40960/35363 [==================================] - 0s 1us/step
# basenji 0.12139462
