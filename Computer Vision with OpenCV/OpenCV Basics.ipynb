# %%
## Import libraries
import cv2
import numpy as np

# %%
cv2.__version__
# Out:
# '4.2.0'

# %%
image = cv2.imread('../Computer Vision with OpenCV/Master OpenCV/images/input.jpg')

# %%
cv2.imshow("first image: ",image)
cv2.waitKey()  ## Important
cv2.destroyAllWindows() ## Important

# %%
image.shape
# Out:
# (830, 1245, 3)

# %%
print('Image height : ', int(image.shape[0]))
print('Image Width : ',)
