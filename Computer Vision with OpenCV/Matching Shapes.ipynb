# %%
import cv2
import numpy as np
import matplotlib.pyplot as plt

# %%
input_image = cv2.imread(r'C:\Users\saket\Desktop\courses\TF\OpenCV\Master OpenCV\images\Capture2.jpg',0)
to_match =cv2.imread(r'C:\Users\saket\Desktop\courses\TF\OpenCV\Master OpenCV\images\someshapes.jpg',0)

# %%
plt.imshow(input_image)

# %%
ret,thresh1 = cv2.threshold(input_image,127,255,0)
ret,thresh2 = cv2.threshold(to_match,127,255,0)

# %%
plt.imshow(thresh1)

# %%
plt.imshow(thresh2)

# %%
cont,h = cv2.findContours(thresh1,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)
sorted_c = sorted(cont,key = cv2.contourArea,reverse = True)

# %%
temp_cont = cont[1]

# %%
cont,h = cv2.findContours(thresh2,cv2.RETR_CCOMP,cv2.CHAIN_APPROX_SIMPLE)

# %%
for c in cont2:
    match = cv2.matchShapes(input_image,c,1,0.0)
    print(match)
    if match<2:
        closest_cont = c
    else:
        closest_cont=[]

cv2.drawContours(to_match,[closest_cont],-1,(0,255,255),3)
plt.imshow(input_image)
# Out:
# 0.972587598303511
# 1.1875981545470695
# 0.9223502539803956
# 1.0670584072409584
# 1.1088682369153342
# 0.9545404065837968
